# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json

# %%
def export_figure (title):
    plt.tight_layout()
    plt.savefig(os.path.join("figs", title + ".png"))
    plt.show()

# %%
samples = "100000"
model_file = "model-women"
results_dir = []
results_file = "cmdstansummary-wg6-seed-1-samples-" + samples + '-model-' + model_file + ".csv"
results = pd.read_csv(os.path.join("model", "results", results_file))
results
# Out:
#                                    Unnamed: 0     mean       sd   hdi_3%  \
# 0                           sigma_topic_women  203.035   39.650  133.091
# 1                             sigma_topic_men  232.835   40.284  162.296
# 2                        sigma_nontopic_women  283.720    9.329  266.325
# 3                          sigma_nontopic_men  341.089   10.615  321.098
# 4                   popularity_topic_women[0]   60.157  105.190 -140.767
# ...                                       ...      ...      ...      ...
# 3397  popularity_module_non_topic_men[30, 49]   -0.392  341.404 -643.743
# 3398  popularity_module_non_topic_men[30, 50]    0.665  340.865 -637.439
# 3399  popularity_module_non_topic_men[30, 51]    0.036  340.940 -644.563
# 3400  popularity_module_non_topic_men[30, 52]   -0.256  341.939 -644.379
# 3401  popularity_module_non_topic_men[30, 53]    0.372  341.088 -640.501
#
#       hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  r_hat
# 0     277.760      2.258    1.598     280.0    2812.0   1.01
# 1     308.859      2.781    1.969     195.0    1398.0   1.01
# 2     301.370      1.292    0.918      52.0     297.0   1.04
# 3     361.037      1.606    1.143      43.0     141.0   1.05
# 4     256.031      0.279    0.197  142515.0  217388.0   1.00
# ...       ...        ...      ...       ...       ...    ...
# 3397  641.457      0.390    0.641  764825.0  275186.0   1.00
# 3398  642.591      0.383    0.637  791969.0  283099.0   1.00
# 3399  637.274      0.404    0.633  711499.0  280676.0   1.00
# 3400  642.962      0.374    0.652  834383.0  276754.0   1.00
# 3401  641.430      0.386    0.634  779568.0  283670.0   1.00
#
# [3402 rows x 10 columns]

# %%
cohorts = pd.read_csv("model/cohorts_with_ids.csv")
cohorts.sort_values('Students3')
# Out:
#     Cohort  AcademicYearStart  Women3  Men3  MaxElectives         institution  \
# 6        4               2022       3    27             6      Durham_England
# 4        4               2020       6    36             6      Durham_England
# 5        4               2021       9    63             6      Durham_England
# 24       4               2022       9    63             1         UofT_Canada
# 22       4               2020      15    72             2         UofT_Canada
# 2        3               2021      12    84            10      Durham_England
# 23       4               2021      15    87             2         UofT_Canada
# 27       1               2022      39   132             7      Uppsala_Sweden
# 26       1               2021      44   131             7      Uppsala_Sweden
# 3        3               2022      54   123            10      Durham_England
# 25       1               2020      46   131             7      Uppsala_Sweden
# 1        3               2020      30   153            10      Durham_England
# 0        3               2022      39   168             3         CAU_Germany
# 19       3               2020      75   387            10         UofT_Canada
# 21       3               2022      75   426             9         UofT_Canada
# 7   3/4/5/               2020     126   399            12  Edinburgh_Scotland
# 10       H               2020     120   447            24    Glasgow_Scotland
# 20       3               2021      84   489            10         UofT_Canada
# 9   3/4/5/               2022     135   444            12  Edinburgh_Scotland
# 8   3/4/5/               2021     150   429            12  Edinburgh_Scotland
# 12       H               2022     129   504            26    Glasgow_Scotland
# 11       H               2021     159   519            24    Glasgow_Scotland
# 28       1               2020     207  1008             6    VirginiaTech_USA
# 29       1               2021     228  1155             6    VirginiaTech_USA
# 30       1               2022     273  1215             6    VirginiaTech_USA
# 15       1               2022     408  1311             7        Kennesaw_USA
# 14       1               2021     438  1485             7        Kennesaw_USA
# 13       1               2020     411  1569             7        Kennesaw_USA
# 16       1               2020     234  1780            28           UOC_Spain
# 17       1               2021     268  1942            28           UOC_Spain
# 18       1               2022     306  2170            29           UOC_Spain
#
#     Students3                           icy  cohort_id  module_count  \
# 6          30           Durham_England42022          6            10
# 4          42           Durham_England42020          4            10
# 5          72           Durham_England42021          5            10
# 24         72              UofT_Canada42022         24             2
# 22         87              UofT_Canada42020         22             1
# 2          96           Durham_England32021          2            17
# 23        102              UofT_Canada42021         23             2
# 27        171           Uppsala_Sweden12022         27            15
# 26        175           Uppsala_Sweden12021         26            15
# 3         177           Durham_England32022          3            17
# 25        177           Uppsala_Sweden12020         25            15
# 1         183           Durham_England32020          1            14
# 0         207              CAU_Germany32022          0            13
# 19        462              UofT_Canada32020         19            10
# 21        501              UofT_Canada32022         21            10
# 7         525  Edinburgh_Scotland3/4/5/2020          7            23
# 10        567         Glasgow_ScotlandH2020         10            24
# 20        573              UofT_Canada32021         20             9
# 9         579  Edinburgh_Scotland3/4/5/2022          9            42
# 8         579  Edinburgh_Scotland3/4/5/2021          8            37
# 12        633         Glasgow_ScotlandH2022         12            26
# 11        678         Glasgow_ScotlandH2021         11            24
# 28       1215         VirginiaTech_USA12020         28            22
# 29       1383         VirginiaTech_USA12021         29            20
# 30       1488         VirginiaTech_USA12022         30            20
# 15       1719             Kennesaw_USA12022         15            52
# 14       1923             Kennesaw_USA12021         14            54
# 13       1980             Kennesaw_USA12020         13            53
# 16       2014                UOC_Spain12020         16            28
# 17       2210                UOC_Spain12021         17            28
# 18       2476                UOC_Spain12022         18            29
#
#     enrolments_total  mu_modules
# 6                150    5.000000
# 4                240    5.714286
# 5                387    5.375000
# 24               111    1.541667
# 22                66    0.758621
# 2                666    6.937500
# 23                90    0.882353
# 27               897    5.245614
# 26               825    4.714286
# 3               1206    6.813559
# 25               861    4.864407
# 1               1245    6.803279
# 0                549    2.652174
# 19               852    1.844156
# 21               831    1.658683
# 7               1695    3.228571
# 10              1851    3.264550
# 20              1095    1.910995
# 9               2115    3.652850
# 8               1956    3.378238
# 12              2034    3.213270
# 11              2319    3.420354
# 28              1839    1.513580
# 29              2016    1.457701
# 30              2571    1.727823
# 15              2703    1.572426
# 14              2937    1.527301
# 13              3174    1.603030
# 16              3873    1.923039
# 17              4557    2.061991
# 18              5361    2.165186

# %%
enrolments = pd.read_csv("model/enrolments_with_ids.csv")
enrolments.sort_values('Students3').head(20)
# Out:
#            MCode  Cohort  AcademicYearStart  Women3  Men3   Cap  \
# 134  cxinfr11092  3/4/5/               2021       0     3   NaN
# 290     CYBR4700       1               2020       0     3   NaN
# 89      COMP4187       4               2022       0     3   NaN
# 396     CYBR3220       1               2022       0     3   NaN
# 310       IT4733       1               2020       3     0   NaN
# 373      SWE4803       1               2021       0     3   NaN
# 364       IT4793       1               2021       3     0   NaN
# 342     CYBR3220       1               2021       0     3   NaN
# 275       CS4522       1               2020       0     3   NaN
# 174  cxinfr11201  3/4/5/               2022       0     3   NaN
# 327       CS4277       1               2021       0     6   NaN
# 44      COMP3421       3               2022       6     0  10.0
# 332       CS4622       1               2021       0     6   NaN
# 537     CSC375H5       3               2022       0     6   NaN
# 333       CS4626       1               2021       3     3   NaN
# 600       CS4144       1               2020       0     6   NaN
# 4    Inf-NumProg       3               2022       0     6   NaN
# 202  COMPSCI4031       H               2020       0     6   NaN
# 41      COMP3621       3               2021       3     3  10.0
# 140  cxinfr11134  3/4/5/               2021       3     3   NaN
#
#             institution  Students3                           icy  cohort_id  \
# 134  Edinburgh_Scotland          3  Edinburgh_Scotland3/4/5/2021          8
# 290        Kennesaw_USA          3             Kennesaw_USA12020         13
# 89       Durham_England          3           Durham_England42022          6
# 396        Kennesaw_USA          3             Kennesaw_USA12022         15
# 310        Kennesaw_USA          3             Kennesaw_USA12020         13
# 373        Kennesaw_USA          3             Kennesaw_USA12021         14
# 364        Kennesaw_USA          3             Kennesaw_USA12021         14
# 342        Kennesaw_USA          3             Kennesaw_USA12021         14
# 275        Kennesaw_USA          3             Kennesaw_USA12020         13
# 174  Edinburgh_Scotland          3  Edinburgh_Scotland3/4/5/2022          9
# 327        Kennesaw_USA          6             Kennesaw_USA12021         14
# 44       Durham_England          6           Durham_England32022          3
# 332        Kennesaw_USA          6             Kennesaw_USA12021         14
# 537         UofT_Canada          6              UofT_Canada32022         21
# 333        Kennesaw_USA          6             Kennesaw_USA12021         14
# 600    VirginiaTech_USA          6         VirginiaTech_USA12020         28
# 4           CAU_Germany          6              CAU_Germany32022          0
# 202    Glasgow_Scotland          6         Glasgow_ScotlandH2020         10
# 41       Durham_England          6           Durham_England32021          2
# 140  Edinburgh_Scotland          6  Edinburgh_Scotland3/4/5/2021          8
#
#                                         icym  module_id
# 134  Edinburgh_Scotland3/4/5/2021cxinfr11092        134
# 290                Kennesaw_USA12020CYBR4700        290
# 89               Durham_England42022COMP4187         89
# 396                Kennesaw_USA12022CYBR3220        396
# 310                  Kennesaw_USA12020IT4733        310
# 373                 Kennesaw_USA12021SWE4803        373
# 364                  Kennesaw_USA12021IT4793        364
# 342                Kennesaw_USA12021CYBR3220        342
# 275                  Kennesaw_USA12020CS4522        275
# 174  Edinburgh_Scotland3/4/5/2022cxinfr11201        174
# 327                  Kennesaw_USA12021CS4277        327
# 44               Durham_England32022COMP3421         44
# 332                  Kennesaw_USA12021CS4622        332
# 537                 UofT_Canada32022CSC375H5        537
# 333                  Kennesaw_USA12021CS4626        333
# 600              VirginiaTech_USA12020CS4144        597
# 4                CAU_Germany32022Inf-NumProg          4
# 202         Glasgow_ScotlandH2020COMPSCI4031        202
# 41               Durham_England32021COMP3621         41
# 140  Edinburgh_Scotland3/4/5/2021cxinfr11134        140

# %%
results.columns = ['variable', 'mean', 'sd', 'c3', 'c97', 'mm', 'ms', 'essb','esst', 'r_hat']
sns.displot(data=results,x='r_hat')
results.sort_values('r_hat', ascending=False).head(40)
# Out:
# /Users/dcs0spb/opt/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
#                                        variable      mean       sd        c3  \
# 1947      popularity_module_non_topic_men[4, 3]  -542.083  678.882 -1391.000
# 2118     popularity_module_non_topic_men[7, 12]  -767.648  919.309 -1810.860
# 441     popularity_module_non_topic_women[7, 9]  -466.479  549.181 -1173.150
# 232    popularity_module_non_topic_women[3, 16]  -529.128  645.029 -1338.870
# 448    popularity_module_non_topic_women[7, 16]  -554.007  651.863 -1324.530
# 112     popularity_module_non_topic_women[1, 4]  -595.810  537.259 -1262.530
# 113     popularity_module_non_topic_women[1, 5]  -374.052  583.598 -1112.180
# 220     popularity_module_non_topic_women[3, 4]  -446.047  659.138 -1257.020
# 8                     popularity_topic_women[4]     7.616  165.306  -262.107
# 501    popularity_module_non_topic_women[8, 15]   230.456  197.864  -105.324
# 217     popularity_module_non_topic_women[3, 1]   313.870  175.582     7.847
# 2107      popularity_module_non_topic_men[7, 1]  -238.488  827.743 -1752.130
# 109     popularity_module_non_topic_women[1, 1]   250.246  180.156   -68.969
# 1415  popularity_module_non_topic_women[25, 11]  -256.704  623.646  -796.533
# 2127     popularity_module_non_topic_men[7, 21]  -230.475  831.127 -1752.930
# 1952      popularity_module_non_topic_men[4, 8]     4.458  581.032 -1114.110
# 1944      popularity_module_non_topic_men[4, 0]  -205.285  592.298 -1339.240
# 1736      popularity_module_non_topic_men[0, 8]   -20.824  700.796 -1343.650
# 1844      popularity_module_non_topic_men[2, 8]  -172.923  731.756 -1532.330
# 1840      popularity_module_non_topic_men[2, 4] -1049.699  692.910 -1618.040
# 1728      popularity_module_non_topic_men[0, 0]  -954.517  695.946 -1535.830
# 1408   popularity_module_non_topic_women[25, 4]   -27.543  541.298 -1053.930
# 613   popularity_module_non_topic_women[10, 19]    66.117  162.162  -223.832
# 567    popularity_module_non_topic_women[9, 27]   130.685  167.164  -165.702
# 167     popularity_module_non_topic_women[2, 5]   281.378  176.073   -32.528
# 667   popularity_module_non_topic_women[11, 19]  -185.010  164.778  -483.608
# 163     popularity_module_non_topic_women[2, 1]   249.292  174.325   -63.106
# 722   popularity_module_non_topic_women[12, 20]  -204.759  166.668  -504.583
# 2438     popularity_module_non_topic_men[13, 8]   224.913  632.038  -888.517
# 2473    popularity_module_non_topic_men[13, 43] -1529.181  568.479 -2025.510
# 1469  popularity_module_non_topic_women[26, 11]   249.935  618.798  -690.086
# 1462   popularity_module_non_topic_women[26, 4]  -523.131  527.174 -1084.270
# 5                     popularity_topic_women[1]   -35.739  110.721  -241.078
# 723   popularity_module_non_topic_women[12, 21]    63.290  161.243  -234.392
# 668   popularity_module_non_topic_women[11, 20]    41.487  161.354  -256.067
# 614   popularity_module_non_topic_women[10, 20]    64.368  161.196  -234.092
# 561    popularity_module_non_topic_women[9, 21]   102.338  128.790  -140.328
# 517    popularity_module_non_topic_women[8, 31]    -2.767  132.990  -251.146
# 452    popularity_module_non_topic_women[7, 20]   -40.261  139.699  -300.639
# 13                    popularity_topic_women[9]   -53.734   44.709  -137.905
#
#           c97       mm       ms  essb  esst  r_hat
# 1947  311.457  334.879  255.987   6.0  73.0   1.74
# 2118  281.094  457.958  350.669   6.0  68.0   1.74
# 441   244.520  269.660  205.971   6.0  73.0   1.73
# 232   283.625  318.035  243.091   6.0  74.0   1.73
# 448   237.518  323.222  247.297   6.0  74.0   1.73
# 112   110.101  263.879  201.564   6.0  73.0   1.73
# 113   369.407  287.379  219.612   6.0  74.0   1.73
# 220   364.549  326.021  249.332   6.0  74.0   1.73
# 8     275.200   73.531   55.331   6.0  76.0   1.71
# 501   569.570   83.113   62.091   6.0  74.0   1.64
# 217   621.276   70.541   52.437   7.0  75.0   1.57
# 2107  391.120  412.016  315.446   7.0  25.0   1.55
# 109   565.225   71.383   52.986   7.0  75.0   1.55
# 1415  923.960  308.200  235.668   7.0  23.0   1.55
# 2127  398.054  413.720  316.754   7.0  24.0   1.54
# 1952  574.601  283.798  216.577   7.0  24.0   1.54
# 1944  347.090  290.724  222.046   7.0  24.0   1.53
# 1736  592.104  346.063  264.585   7.0  24.0   1.53
# 1844  423.771  363.022  277.773   7.0  24.0   1.53
# 1840  249.001  343.511  262.812   7.0  24.0   1.53
# 1728  353.317  344.622  263.610   7.0  24.0   1.53
# 1408  481.920  265.505  202.760   7.0  24.0   1.53
# 613   353.777   62.292   46.095   7.0  73.0   1.51
# 567   431.468   63.316   46.791   7.0  75.0   1.48
# 167   600.041   65.679   48.470   8.0  74.0   1.46
# 667   108.704   61.522   45.405   8.0  74.0   1.46
# 163   566.260   63.526   46.784   8.0  75.0   1.43
# 722    97.600   60.814   44.792   8.0  73.0   1.43
# 2438  845.901  283.030  213.166   8.0  34.0   1.42
# 2473 -457.604  254.002  191.659   8.0  33.0   1.41
# 1469  899.221  259.782  194.062   9.0  53.0   1.39
# 1462  327.513  219.365  163.702   9.0  60.0   1.37
# 5     169.105   34.068   24.788  11.0  83.0   1.27
# 723   362.960   49.303   35.860  11.0  85.0   1.26
# 668   342.735   49.199   35.778  11.0  85.0   1.26
# 614   364.784   48.056   34.903  11.0  88.0   1.25
# 561   338.853   37.335   27.075  12.0  90.0   1.23
# 517   243.718   38.260   27.735  12.0  92.0   1.22
# 452   219.542   39.455   28.575  13.0  93.0   1.21
# 13     28.966   12.261    8.867  13.0  88.0   1.20

# %%
all_topics = pd.read_csv(os.path.join('curriculum_content','ACM_2023_CAH_codes.csv'))
all_acm_topics = sorted(list(all_topics[all_topics['Area'] != 'Non-CS application']['Abbrev']))
all_cah_topics = sorted(list(set(all_topics['Abbrev']) -  set(all_acm_topics)))
all_topics
# Out:
#                                               Title Abbrev                Area
# 0                         Algorithms and Complexity     AL            Software
# 1                     Architecture and Organization     AR             Systems
# 2                           Artificial Intelligence     AI        Applications
# 3                                   Data Management     DM             Systems
# 4              Foundations of Programming Languages    FPL            Software
# 5               Graphics and Interactive Techniques    GIT        Applications
# 6                        Human-Computer Interaction    HCI        Applications
# 7          Mathematical and Statistical Foundations    MSF        Underpinning
# 8                      Networking and Communication     NC             Systems
# 9                                 Operating Systems     OS             Systems
# 10               Parallel and Distributed Computing    PDC             Systems
# 11                                         Security    SEC             Systems
# 12              Society, Ethics and Professionalism    SEP        Underpinning
# 13                Software Development Fundamentals    SDF            Software
# 14                             Software Engineering     SE            Software
# 15                 Specialized Platform Development    SPD        Applications
# 16                             Systems Fundamentals     SF             Systems
# 17                           medicine and dentistry     01  Non-CS application
# 18                      subjects allied to medicine     02  Non-CS application
# 19                    biological and sport sciences     03  Non-CS application
# 20                                       psychology     04  Non-CS application
# 21                              veterinary sciences     05  Non-CS application
# 22            agriculture, food and related studies     06  Non-CS application
# 23                                physical sciences     07  Non-CS application
# 24                            mathematical sciences     09  Non-CS application
# 25                       engineering and technology     10  Non-CS application
# 26           geographical and environmental studies     12  Non-CS application
# 27              architecture, building and planning     13  Non-CS application
# 28                      humanities and liberal arts     14  Non-CS application
# 29                                  social sciences     15  Non-CS application
# 30                                              law     16  Non-CS application
# 31                          business and management     17  Non-CS application
# 32                         communications and media     18  Non-CS application
# 33                        language and area studies     19  Non-CS application
# 34  historical, philosophical and religious studies     20  Non-CS application
# 35                         creative arts and design     21  Non-CS application
# 36                           education and teaching     22  Non-CS application

# %%
def topic_title(abbrev):
    title = all_topics[all_topics.Abbrev==abbrev].Title.item()
    return title

# %%
topic_title("AL")
# Out:
# finding topic for  AL
# title is  Algorithms and Complexity
# 'Algorithms and Complexity'

# %%
with open(os.path.join('model','topics.json'), 'rb') as fp:
    topics = json.load(fp)

acm_topics = [topic for topic in topics if topic in all_acm_topics]
cah_topics = [topic for topic in topics if topic in all_cah_topics]
topics
# Out:
# ['02',
#  '03',
#  '04',
#  '07',
#  '15',
#  '16',
#  '17',
#  '21',
#  '22',
#  'AI',
#  'AL',
#  'AR',
#  'DM',
#  'FPL',
#  'GIT',
#  'HCI',
#  'MSF',
#  'NC',
#  'OS',
#  'PDC',
#  'SDF',
#  'SE',
#  'SEC',
#  'SEP',
#  'SPD']

# %%
# pop_topic_all_means = []
# pop_topic_all_rhats = []
# pop_topic_all_c3 = []
# pop_topic_all_c97 = []

# pop_topic_wm_diff_means = []
# pop_topic_wm_diff_rhats = []
# pop_topic_wm_diff_c3 = []
# pop_topic_wm_diff_c97 = []

pop_topic_women_means = []
pop_topic_women_rhats = []
pop_topic_women_c3 = []
pop_topic_women_c97 = []

pop_topic_men_means = []
pop_topic_men_rhats = []
pop_topic_men_c3 = []
pop_topic_men_c97 = []

topic_titles = []

for i, topic in enumerate(topics):
    row = results[results['variable'] == "popularity_topic_women[" + str(i) + "]"]
    pop_topic_women_means.append(row.iloc[0]['mean'])
    pop_topic_women_rhats.append(row.iloc[0]['r_hat'])
    pop_topic_women_c3.append(row.iloc[0]['c3'])
    pop_topic_women_c97.append(row.iloc[0]['c97'])

    row = results[results['variable'] == "popularity_topic_men[" + str(i) + "]"]
    pop_topic_men_means.append(row.iloc[0]['mean'])
    pop_topic_men_rhats.append(row.iloc[0]['r_hat'])
    pop_topic_men_c3.append(row.iloc[0]['c3'])
    pop_topic_men_c97.append(row.iloc[0]['c97'])
    
    topic_titles.append(topic_title(topic))



    
df = pd.DataFrame({"topic": topics, 
                   "topic_title": topic_titles,
                   "pop_topic_women_mean": pop_topic_women_means, 
                   "pop_topic_men_mean": pop_topic_men_means,
                   "pop_topic_women_rhat": pop_topic_women_rhats, 
                   "pop_topic_men_rhat": pop_topic_men_rhats,
                   "pop_topic_women_c3": pop_topic_women_c3,
                   "pop_topic_women_c97": pop_topic_women_c97,
                   "pop_topic_men_c3": pop_topic_men_c3,
                   "pop_topic_men_c97": pop_topic_men_c97,      
                  })


df.sort_values('pop_topic_women_mean', inplace=True)

def plot_with_errors(df, prop, topics, xlabel, ylabel, with_errors=True):
    if prop in ["pop_women", "pop_men"]:
        col = prop
    else:
        col = 'pop_topic_' + prop + '_mean'
#    data = df[df['topic'].isin(topics)].sort_values(col)
    data = df[df['topic'].isin(topics)].sort_values("pop_topic_women_mean")

    y = data[col]

    fig, ax = plt.subplots()
    fig.set_figheight(7)
    ax.set_ylim(-900,900)
    ax.axhline(0, color = 'lightgrey', linestyle = 'dashed', linewidth=1)
    ax.plot(data['topic_title'], y,'ob')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.tick_params("x", rotation=90)
    

    
    if with_errors:
        c97 = 'pop_topic_' + prop + '_c97'
        c3 = 'pop_topic_' + prop + '_c3'

        data['upper_error'] = data[c97] - data[col]
        data['lower_error'] = data[col] - data[c3]
        ax.errorbar(data['topic_title'], y, elinewidth=1, ecolor='black', capsize=3, yerr=[data['lower_error'], data['upper_error']])


    
#    sns.barplot(ax=ax, data=data, x='topic', y='pop_topic_' + prop + '_mean', orient='v')

# %%
plot_with_errors(df, 'women', acm_topics, "Computing curriculum topics", "Popularity with women")
export_figure("results_acm_women" + samples)

# %%
plot_with_errors(df, 'men', acm_topics, "Computing curriculum topics", "Popularity with men")
export_figure("results_acm_men" + samples)

# %%
plot_with_errors(df, 'women', cah_topics, "Non-CS application areas", "Popularity with women")
export_figure("results_cah_women" + samples)

# %%
plot_with_errors(df, 'men', cah_topics, "Non-CS application areas", "Popularity with men")
export_figure("results_cah_men" + samples)

# %%
df.sort_values('pop_topic_women_mean')
# Out:
#    topic  pop_topic_women_mean  pop_topic_men_mean  pop_topic_women_rhat  \
# 19   PDC              -473.204            -479.910                  1.01
# 3     07              -358.217             -74.064                  1.01
# 13   FPL              -313.437            -684.840                  1.12
# 10    AL              -306.604            -266.455                  1.01
# 11    AR              -249.191            -167.131                  1.01
# 8     22              -169.814            -275.568                  1.00
# 18    OS              -165.613            -281.502                  1.02
# 14   GIT              -134.826             -25.659                  1.00
# 24   SPD              -125.441             -80.418                  1.02
# 17    NC               -67.363             -38.379                  1.02
# 9     AI               -53.734              -3.310                  1.20
# 2     04               -37.005            -149.297                  1.13
# 1     03               -35.739             -17.831                  1.27
# 16   MSF               -19.278              49.949                  1.07
# 6     17               -17.448              26.365                  1.01
# 22   SEC               -16.963              20.500                  1.01
# 12    DM                -8.901            -102.100                  1.01
# 4     15                 7.616             103.704                  1.71
# 23   SEP                 8.102             -81.979                  1.01
# 21    SE                10.136              23.498                  1.02
# 5     16                32.922              16.069                  1.00
# 15   HCI                52.460             -37.219                  1.01
# 0     02                60.157            -125.170                  1.00
# 7     21                69.440              22.492                  1.00
# 20   SDF               254.454             222.761                  1.00
#
#     pop_topic_men_rhat  pop_topic_women_c3  pop_topic_women_c97  \
# 19                1.09            -608.378             -338.822
# 3                 1.00            -731.343               25.771
# 13                1.03            -424.663             -200.913
# 10                1.01            -389.323             -222.779
# 11                1.01            -401.729              -96.468
# 8                 1.00            -348.004                5.481
# 18                1.01            -322.449               -9.850
# 14                1.00            -241.874              -27.039
# 24                1.01            -230.684              -21.196
# 17                1.01            -167.145               33.467
# 9                 1.01            -137.905               28.966
# 2                 1.00            -262.863              190.407
# 1                 1.00            -241.078              169.105
# 16                1.00            -124.041               82.991
# 6                 1.00            -121.663               88.043
# 22                1.01             -93.266               59.092
# 12                1.12            -106.048               87.862
# 4                 1.00            -262.107              275.200
# 23                1.01             -80.247               96.304
# 21                1.01             -88.961              110.059
# 5                 1.00            -158.367              225.068
# 15                1.01             -58.832              164.071
# 0                 1.00            -140.767              256.031
# 7                 1.00            -111.795              250.216
# 20                1.00              23.837              483.737
#
#     pop_topic_men_c3  pop_topic_men_c97
# 19          -633.088           -328.213
# 3           -394.565            244.736
# 13          -797.583           -569.319
# 10          -360.350           -173.047
# 11          -333.677             -3.338
# 8           -475.977            -72.111
# 18          -453.415           -109.433
# 14          -146.330             96.511
# 24          -197.785             36.750
# 17          -153.855             75.860
# 9            -87.168             78.510
# 2           -389.993             92.309
# 1           -215.179            175.789
# 16           -63.164            163.832
# 6            -95.563            149.387
# 22           -68.005            110.116
# 12          -228.180             23.286
# 4            -70.983            278.055
# 23          -182.751             22.002
# 21           -91.649            138.696
# 5           -206.154            239.322
# 15          -170.658             93.178
# 0           -364.282            112.199
# 7           -182.981            231.614
# 20           -42.007            492.014

# %%
df.sort_values('pop_topic_men_mean')
# Out:
#    topic  pop_topic_women_mean  pop_topic_men_mean  pop_topic_women_rhat  \
# 13   FPL              -313.437            -684.840                  1.12
# 19   PDC              -473.204            -479.910                  1.01
# 18    OS              -165.613            -281.502                  1.02
# 8     22              -169.814            -275.568                  1.00
# 10    AL              -306.604            -266.455                  1.01
# 11    AR              -249.191            -167.131                  1.01
# 2     04               -37.005            -149.297                  1.13
# 0     02                60.157            -125.170                  1.00
# 12    DM                -8.901            -102.100                  1.01
# 23   SEP                 8.102             -81.979                  1.01
# 24   SPD              -125.441             -80.418                  1.02
# 3     07              -358.217             -74.064                  1.01
# 17    NC               -67.363             -38.379                  1.02
# 15   HCI                52.460             -37.219                  1.01
# 14   GIT              -134.826             -25.659                  1.00
# 1     03               -35.739             -17.831                  1.27
# 9     AI               -53.734              -3.310                  1.20
# 5     16                32.922              16.069                  1.00
# 22   SEC               -16.963              20.500                  1.01
# 7     21                69.440              22.492                  1.00
# 21    SE                10.136              23.498                  1.02
# 6     17               -17.448              26.365                  1.01
# 16   MSF               -19.278              49.949                  1.07
# 4     15                 7.616             103.704                  1.71
# 20   SDF               254.454             222.761                  1.00
#
#     pop_topic_men_rhat  pop_topic_women_c3  pop_topic_women_c97  \
# 13                1.03            -424.663             -200.913
# 19                1.09            -608.378             -338.822
# 18                1.01            -322.449               -9.850
# 8                 1.00            -348.004                5.481
# 10                1.01            -389.323             -222.779
# 11                1.01            -401.729              -96.468
# 2                 1.00            -262.863              190.407
# 0                 1.00            -140.767              256.031
# 12                1.12            -106.048               87.862
# 23                1.01             -80.247               96.304
# 24                1.01            -230.684              -21.196
# 3                 1.00            -731.343               25.771
# 17                1.01            -167.145               33.467
# 15                1.01             -58.832              164.071
# 14                1.00            -241.874              -27.039
# 1                 1.00            -241.078              169.105
# 9                 1.01            -137.905               28.966
# 5                 1.00            -158.367              225.068
# 22                1.01             -93.266               59.092
# 7                 1.00            -111.795              250.216
# 21                1.01             -88.961              110.059
# 6                 1.00            -121.663               88.043
# 16                1.00            -124.041               82.991
# 4                 1.00            -262.107              275.200
# 20                1.00              23.837              483.737
#
#     pop_topic_men_c3  pop_topic_men_c97
# 13          -797.583           -569.319
# 19          -633.088           -328.213
# 18          -453.415           -109.433
# 8           -475.977            -72.111
# 10          -360.350           -173.047
# 11          -333.677             -3.338
# 2           -389.993             92.309
# 0           -364.282            112.199
# 12          -228.180             23.286
# 23          -182.751             22.002
# 24          -197.785             36.750
# 3           -394.565            244.736
# 17          -153.855             75.860
# 15          -170.658             93.178
# 14          -146.330             96.511
# 1           -215.179            175.789
# 9            -87.168             78.510
# 5           -206.154            239.322
# 22           -68.005            110.116
# 7           -182.981            231.614
# 21           -91.649            138.696
# 6            -95.563            149.387
# 16           -63.164            163.832
# 4            -70.983            278.055
# 20           -42.007            492.014

# %%
print(results[results['variable'].str.contains('sigma')][['variable','mean','c3','c97','r_hat']].to_latex(index=False))
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#             variable &    mean &      c3 &     c97 &  r\_hat \\
# \midrule
#    sigma\_topic\_women & 207.131 & 138.372 & 285.110 &   1.02 \\
#      sigma\_topic\_men & 240.152 & 167.103 & 317.319 &   1.00 \\
# sigma\_nontopic\_women & 281.442 & 264.619 & 298.968 &   1.04 \\
#   sigma\_nontopic\_men & 336.252 & 316.355 & 356.559 &   1.03 \\
# \bottomrule
# \end{tabular}
# /var/folders/my/th4q3hxs0b7c1t1qlv0j2dtm0000gp/T/ipykernel_66353/1296689431.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(results[results['variable'].str.contains('sigma')][['variable','mean','c3','c97','r_hat']].to_latex(index=False))
