# %%
import pandas as pd
import os

# %%
dump_files = ["20230622WG6_AllElectivesPart1-stage1.csv", "20230622WG6_AllElectivesPart2-stage1.csv","20230622WG6_AllElectivesPart2-stage1.csv"]
dump_contents = []
for dump_file in dump_files:
    raw = pd.read_csv(os.path.join("coded",dump_file), dtype='string').fillna("")
    dump_contents.append(raw)
raw_coded = pd.concat(dump_contents)
annotated = raw_coded[raw_coded['Annotations'].str.len() >0]
annotated.columns
# Out:
# Index(['Title', 'Text', '[M] elective: ', '[M] institution: ', '[M] title: ',
#        '[C] Barker, Lecia', '[C] Bradley, Steven', '[C] Hooshangi, Sara',
#        '[C] Kunkeler, Thom', '[C] Lennon, Ruth', '[C] Parkinson, Jack',
#        '[C] Sibia, Naaz (Naaz Sibia)', 'Annotations',
#        '[C] Altin, Rukiye (rukiye)', '[C] McNeill, Fiona',
#        '[C] Minguillón, Julià (Julià Minguillón)', '[C] Parker, Miranda',
#        '[C] Peltsverger, Svetlana'],
#       dtype='object')

# %%
meta_cols = []
renamer = {}
for col in annotated.columns:
    shortened = col
    if col[0:3] == "[M]":
        print ("[M] " )
        shortened = col[4:-2]
        meta_cols.append(shortened)
    renamer[col] = shortened

renamer
# Out:
# [M]
# [M]
# [M]
# {'Title': 'Title',
#  'Text': 'Text',
#  '[M] elective: ': 'elective',
#  '[M] institution: ': 'institution',
#  '[M] title: ': 'title',
#  '[C] Barker, Lecia': '[C] Barker, Lecia',
#  '[C] Bradley, Steven': '[C] Bradley, Steven',
#  '[C] Hooshangi, Sara': '[C] Hooshangi, Sara',
#  '[C] Kunkeler, Thom': '[C] Kunkeler, Thom',
#  '[C] Lennon, Ruth': '[C] Lennon, Ruth',
#  '[C] Parkinson, Jack': '[C] Parkinson, Jack',
#  '[C] Sibia, Naaz (Naaz Sibia)': '[C] Sibia, Naaz (Naaz Sibia)',
#  'Annotations': 'Annotations',
#  '[C] Altin, Rukiye (rukiye)': '[C] Altin, Rukiye (rukiye)',
#  '[C] McNeill, Fiona': '[C] McNeill, Fiona',
#  '[C] Minguillón, Julià (Julià Minguillón)': '[C] Minguillón, Julià (Julià Minguillón)',
#  '[C] Parker, Miranda': '[C] Parker, Miranda',
#  '[C] Peltsverger, Svetlana': '[C] Peltsverger, Svetlana'}

# %%
# first two meta columns are elective code and institution, which we use as the index
# third meta column is title
index_cols = meta_cols[0:2]
keep_cols = index_cols + ["Annotations"]
export = annotated.rename(columns=renamer)[keep_cols]

# Ignore the Uppsala electives with no content
export = export[~(export.institution=="Uppsala_Sweden")]
export = export[~(export.elective.isin(["cxinfr11245","cxinfr11246","cxinfr11248","cxinfr11083"]))]
export.to_csv("annotated_electives.csv")
export
# Out:
#         elective       institution  \
# 1       COMP3491    Durham_England
# 2       COMP3507    Durham_England
# 7       COMP3621    Durham_England
# 10      COMP3677    Durham_England
# 12      COMP4117    Durham_England
# 13      COMP4127    Durham_England
# 16      COMP4187    Durham_England
# 18   cxinfr08033      Edinburgh_UK
# 19   cxinfr10052      Edinburgh_UK
# 23   cxinfr10084      Edinburgh_UK
# 27   cxinfr10083      Edinburgh_UK
# 32   cxinfr11209      Edinburgh_UK
# 34   cxinfr11099      Edinburgh_UK
# 57      inf-EAeS       CAU_Germany
# 63      inf-EERP       CAU_Germany
# 64     CGDD2012L      Kennesaw_USA
# 65        IT4123      Kennesaw_USA
# 66        IT4203      Kennesaw_USA
# 77       CSE4983      Kennesaw_USA
# 90        IT4603      Kennesaw_USA
# 93        IT4893      Kennesaw_USA
# 96       SWE4803      Kennesaw_USA
# 104        5.579         UOC_Spain
# 116       CS3744  VirginiaTech_USA
# 119       CS4134  VirginiaTech_USA
# 127       CS4704  VirginiaTech_USA
# 128       CS4784  VirginiaTech_USA
# 129       CS4884  VirginiaTech_USA
#
#                                            Annotations
# 1    Annotation: I think this is security because o...
# 2    Annotation: Low confidence on this. Complexity...
# 7    Annotation: This seems like the independent pr...
# 10   Annotation: This is related to AI, but also to...
# 12   Annotation: quantum computing; User: Sara Hoos...
# 13   Annotation: very low confidence; User: Lecia B...
# 16   Annotation: could be one of many sciences; Use...
# 18   Annotation: ; User: Jack Parkinson; Timestamp:...
# 19   Annotation: According to the ACM 2023 curricul...
# 23   Annotation: As with previous experiential lear...
# 27   Annotation: data science is not always about A...
# 32   Annotation: Computational Neuroscience; User: ...
# 34   Annotation: Quantum Computing; User: Sara Hoos...
# 57   Annotation: Really don't know... AI? AL?; User...
# 63   Annotation: I don't know what an ERP system is...
# 64   Annotation: this should probably be removed, u...
# 65   Annotation: not sure if SPD is right, but the ...
# 66   Annotation: Not sure if the web is a specializ...
# 77   Annotation: Internship; User: Sara Hooshangi; ...
# 90   Annotation: Blockchain; User: Sara Hooshangi; ...
# 93   Annotation: The title of the module includes I...
# 96   Annotation: Not quite game design enough for g...
# 104  Annotation: applied AL because the ACM doc inc...
# 116  Annotation: ; User: Lecia Barker; Timestamp: 6...
# 119  Annotation: Quantum Computation; User: Sara Ho...
# 127  Annotation: Is this really an elective?; User:...
# 128  Annotation: is this really an elective?; User:...
# 129  Annotation: Not sure that AL is the right tech...
